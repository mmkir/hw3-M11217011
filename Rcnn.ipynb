# %% [markdown]
# # ***Load Pre-train Model***

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn
model = fasterrcnn_resnet50_fpn(pretrain=True)

# %%
model
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-3): 4 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#   )
# )

# %% [markdown]
# # ***Read Dataset***

# %%
train_img_path = "資料集/貨櫃資料集_縮放/訓練集_image"
val_img_path   = "資料集/貨櫃資料集_縮放/驗證集_image"

train_label_path = "資料集/貨櫃資料集_縮放/訓練集_xml"
val_label_path   = "資料集/貨櫃資料集_縮放/驗證集_xml"

# %%
# ContainerDataset
from package.function import ContainerDataset,Transform
from torch.utils.data import DataLoader
import torch

# %%
train_dataset = ContainerDataset(train_img_path, train_label_path, transform=Transform())
val_dataset   = ContainerDataset(val_img_path, val_label_path, transform=Transform())

# %%
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=False)
val_loader   = DataLoader(val_dataset, batch_size=4, shuffle=False)

# %% [markdown]
# # ***Train Model***

# %%
import torch.nn as nn
import torch.optim as optim

# %%
epoch_size = 200
CUDA = True
patience = 20
save_path = 'best_model/Rcnn.pth'
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x0000026572222710>

# %%
import sys
import time

model.train()
# 移动模型到 GPU
if CUDA:
    model = model.cuda()
loss,patime = 100,0

for epoch in range(epoch_size):
    train_loss = 0.0
    for batch_idx, (images, targets) in enumerate(train_loader):
        sys.stdout.write(f'\rEpoch [{epoch+1}/{epoch_size}],目前循環次數: [{batch_idx+1}/{len(train_loader)}]')
        # 调整 targets 的格式
        targets = [{'boxes': t[0].unsqueeze(0), 'labels': torch.ones((1,), dtype=torch.int64)} for t in targets]

        if CUDA:
            images = images.cuda()
            targets = [{k: v.cuda() for k, v in t.items()} for t in targets]



        # clear gradient
        optimizer.zero_grad()
        # Forward propagation
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        # Calculate gradients
        losses.backward()
        # Update parameters
        optimizer.step()
        train_loss += losses.item()
    # 驗證
    val_loss,len_val = 0.0,len(val_loader)
    for valbatch_idx, (imgs, tgs) in enumerate(val_loader):
        tgs = [{'boxes': t[0].unsqueeze(0), 'labels': torch.ones((1,), dtype=torch.int64)} for t in tgs]
        if CUDA:
            imgs = imgs.cuda()
            tgs = [{k: v.cuda() for k, v in t.items()} for t in tgs]
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
            val_loss += losses.item()
    val_loss = val_loss / len_val
    # 
    print(f'\nEpoch [{epoch+1}/{epoch_size}], train_Loss: {train_loss/len(train_loader):.4f}, val_Loss: {val_loss:.4f}')
    # EarlyStopping
    if loss > val_loss:
        patime = 0
        loss = val_loss
        torch.save(model, save_path)
    else:
        patime += 1 
    if patime == patience:
        break
# Out:
# Epoch [1/200],目前循環次數: [1/532]
# c:\Users\Ming Hong\.conda\envs\PYtorch\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch [1/200],目前循環次數: [532/532]
# Epoch [1/200], train_Loss: 0.3027, val_Loss: 0.0929
# Epoch [2/200],目前循環次數: [532/532]
# Epoch [2/200], train_Loss: 0.0824, val_Loss: 0.0198
# Epoch [3/200],目前循環次數: [532/532]
# Epoch [3/200], train_Loss: 0.0584, val_Loss: 0.0347
# Epoch [4/200],目前循環次數: [532/532]
# Epoch [4/200], train_Loss: 0.0569, val_Loss: 0.0308
# Epoch [5/200],目前循環次數: [532/532]
# Epoch [5/200], train_Loss: 0.0489, val_Loss: 0.0309
# Epoch [6/200],目前循環次數: [532/532]
# Epoch [6/200], train_Loss: 0.0456, val_Loss: 0.0273
# Epoch [7/200],目前循環次數: [532/532]
# Epoch [7/200], train_Loss: 0.0401, val_Loss: 0.0205
# Epoch [8/200],目前循環次數: [532/532]
# Epoch [8/200], train_Loss: 57007.6350, val_Loss: 0.3557
# Epoch [9/200],目前循環次數: [532/532]
# Epoch [9/200], train_Loss: 87122.1412, val_Loss: 222.1700
# Epoch [10/200],目前循環次數: [532/532]
# Epoch [10/200], train_Loss: 430.5008, val_Loss: 9.4225
# Epoch [11/200],目前循環次數: [532/532]
# Epoch [11/200], train_Loss: 233.8740, val_Loss: 5.6312
# Epoch [12/200],目前循環次數: [532/532]
# Epoch [12/200], train_Loss: 53.6896, val_Loss: 0.2772
# Epoch [13/200],目前循環次數: [532/532]
# Epoch [13/200], train_Loss: 5.6777, val_Loss: 0.3373
# Epoch [14/200],目前循環次數: [532/532]
# Epoch [14/200], train_Loss: 5.3067, val_Loss: 0.3845
# Epoch [15/200],目前循環次數: [532/532]
# Epoch [15/200], train_Loss: 2.7125, val_Loss: 0.1414
# Epoch [16/200],目前循環次數: [532/532]
# Epoch [16/200], train_Loss: 11.9655, val_Loss: 0.0819
# Epoch [17/200],目前循環次數: [532/532]
# Epoch [17/200], train_Loss: 3.0840, val_Loss: 0.0812
# Epoch [18/200],目前循環次數: [532/532]
# Epoch [18/200], train_Loss: 1.8221, val_Loss: 0.0785
# Epoch [19/200],目前循環次數: [532/532]
# Epoch [19/200], train_Loss: 1.4030, val_Loss: 0.0802
# Epoch [20/200],目前循環次數: [532/532]
# Epoch [20/200], train_Loss: 3.9347, val_Loss: 0.0798
# Epoch [21/200],目前循環次數: [532/532]
# Epoch [21/200], train_Loss: 1.8093, val_Loss: 0.0793
# Epoch [22/200],目前循環次數: [532/532]
# Epoch [22/200], train_Loss: 0.6286, val_Loss: 0.0791

# %% [markdown]
# # ***評估 測試集性能***

# %%
# model性能評估
import torch
from package.function import *
# 用最佳model進行物件偵測
model = torch.load('best_model/Rcnn.pth')

folderpath = '資料集/貨櫃資料集/測試集/'
filenames = find_filename(folder_path=folderpath,File_extension='jpg')[0]
file = [folderpath+filename for filename in filenames]
images = load_images(file)
results = predict_images(model, images,'cuda')

# %%
for i, result in enumerate(results):
    print(f"Image {i+1} Predictions:")
    print(result)
# Out:
# Image 1 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 2 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 3 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 4 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 5 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 6 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 7 Predictions:
# [{'boxes': tensor([[ 780.8938,    1.0867,  984.7698,   93.6038],
#         [ 889.3931,    8.8006, 1023.2875,   92.0100],
#         [ 811.6953,   15.2724,  935.2779,   99.9449]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.2473, 0.2280, 0.0619], device='cuda:0')}]
# Image 8 Predictions:
# [{'boxes': tensor([[ 769.4406,    7.1533,  987.8765,  102.5723],
#         [ 897.1440,   18.1963, 1025.6359,  103.3233],
#         [ 815.4100,  121.1578, 1008.6171,  248.3915]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.0987, 0.0960, 0.0634], device='cuda:0')}]
# Image 9 Predictions:
# [{'boxes': tensor([[ 914.2756,   35.6255, 1030.2775,  112.8503]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0629], device='cuda:0')}]
# Image 10 Predictions:
# [{'boxes': tensor([[865.9109,   0.0000, 989.1099,  70.0254]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7214], device='cuda:0')}]
# Image 11 Predictions:
# [{'boxes': tensor([[749.5532,  14.2016, 910.2057, 121.0484],
#         [720.2789, 132.7411, 930.7501, 262.1377]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.3882, 0.0525], device='cuda:0')}]
# Image 12 Predictions:
# [{'boxes': tensor([[690.8489,  32.0809, 869.6301, 143.9154]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.5163], device='cuda:0')}]
# Image 13 Predictions:
# [{'boxes': tensor([[649.2783,  59.6062, 848.4539, 173.9378]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.5304], device='cuda:0')}]
# Image 14 Predictions:
# [{'boxes': tensor([[628.5082,  84.1403, 846.4764, 202.6128]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8957], device='cuda:0')}]
# Image 15 Predictions:
# [{'boxes': tensor([[623.8594,  96.8761, 870.6267, 222.0948],
#         [482.8496, 811.7700, 673.8909, 928.5092]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.3981, 0.0878], device='cuda:0')}]
# Image 16 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 17 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 18 Predictions:
# [{'boxes': tensor([[ 846.1696,    1.3098, 1026.9491,   89.8366],
#         [ 869.6582,  104.5541, 1034.9454,  217.9211]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7459, 0.1146], device='cuda:0')}]
# Image 19 Predictions:
# [{'boxes': tensor([[ 829.2176,   27.2434, 1057.9242,  131.1944]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0764], device='cuda:0')}]
# Image 20 Predictions:
# [{'boxes': tensor([[ 843.6597,   56.4301, 1034.1248,  169.5356]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2970], device='cuda:0')}]
# Image 21 Predictions:
# [{'boxes': tensor([[ 847.9094,   56.7237, 1044.9435,  174.2946]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2604], device='cuda:0')}]
# Image 22 Predictions:
# [{'boxes': tensor([[ 847.1075,   55.9046, 1044.7694,  172.3118]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4792], device='cuda:0')}]
# Image 23 Predictions:
# [{'boxes': tensor([[ 846.8805,   56.0269, 1046.9325,  172.5932]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3326], device='cuda:0')}]
# Image 24 Predictions:
# [{'boxes': tensor([[ 813.6133,    0.0000, 1020.5186,   73.6023],
#         [ 756.2145,  426.3411,  883.8042,  516.9139]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9600, 0.0624], device='cuda:0')}]
# Image 25 Predictions:
# [{'boxes': tensor([[ 832.4565,    5.2397, 1023.2761,  114.8082],
#         [ 823.1368,   30.8834,  894.9937,   88.3247]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.6473, 0.0532], device='cuda:0')}]
# Image 26 Predictions:
# [{'boxes': tensor([[ 850.4512,    0.0000, 1037.0283,   82.6262]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8906], device='cuda:0')}]
# Image 27 Predictions:
# [{'boxes': tensor([[ 894.2602,   91.5971, 1102.0564,  215.4207]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1804], device='cuda:0')}]
# Image 28 Predictions:
# [{'boxes': tensor([[ 892.4146,   91.7120, 1103.1360,  217.0934]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1979], device='cuda:0')}]
# Image 29 Predictions:
# [{'boxes': tensor([[ 834.8347,    0.0000, 1033.6742,   78.4317]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9794], device='cuda:0')}]
# Image 30 Predictions:
# [{'boxes': tensor([[ 820.4949,   18.4646, 1045.0547,  135.8442],
#         [ 920.0375,   28.1807,  985.9005,  144.7949]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.5536, 0.0722], device='cuda:0')}]
# Image 31 Predictions:
# [{'boxes': tensor([[ 812.5304,   29.2224, 1042.8749,  144.3317],
#         [ 668.6453,  572.9986,  870.4826,  678.9129]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.5217, 0.2158], device='cuda:0')}]
# Image 32 Predictions:
# [{'boxes': tensor([[ 828.6343,   49.6424, 1060.8719,  163.0247],
#         [ 937.1217,   61.0556, 1008.0120,  175.8498]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.4766, 0.1018], device='cuda:0')}]
# Image 33 Predictions:
# [{'boxes': tensor([[ 825.2767,  105.8372, 1087.7933,  227.2093],
#         [1001.5940,  123.8370, 1137.1898,  213.5756],
#         [ 678.4960,  830.6120,  894.0773,  959.8005],
#         [ 938.9709,  110.7982, 1127.2389,  239.8858]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.7318, 0.0937, 0.0522, 0.0501], device='cuda:0')}]
# Image 34 Predictions:
# [{'boxes': tensor([[ 909.1485,  118.8238, 1097.0107,  258.4175],
#         [1005.1037,  135.0316, 1143.7375,  224.6012]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.2692, 0.0778], device='cuda:0')}]
# Image 35 Predictions:
# [{'boxes': tensor([[ 912.2728,   89.3962, 1093.0551,  221.9425]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2239], device='cuda:0')}]
# Image 36 Predictions:
# [{'boxes': tensor([[760.8967,  10.2334, 972.5601,  85.2330]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8997], device='cuda:0')}]
# Image 37 Predictions:
# [{'boxes': tensor([[ 807.3901,   38.3218, 1016.7865,  147.5451],
#         [ 589.0597,  239.1012,  678.8720,  301.1271],
#         [ 863.2619,   53.0349,  979.9890,  139.2058]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.9350, 0.1147, 0.0517], device='cuda:0')}]
# Image 38 Predictions:
# [{'boxes': tensor([[ 780.9032,   70.1951, 1029.5215,  175.3331],
#         [ 894.3022,   76.9992,  957.9340,  193.3676],
#         [ 879.8217,   82.5061, 1005.5520,  176.2472],
#         [ 558.8668,  298.0559,  638.6243,  355.2881]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.8300, 0.1734, 0.0691, 0.0534], device='cuda:0')}]
# Image 39 Predictions:
# [{'boxes': tensor([[ 803.8851,  101.6818, 1021.3240,  233.5217],
#         [ 885.4285,  110.5798,  950.5675,  236.5629]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.6062, 0.1330], device='cuda:0')}]
# Image 40 Predictions:
# [{'boxes': tensor([[839.8519,  47.1836, 989.1450, 164.6327],
#         [567.2067, 258.6197, 644.0891, 317.4524],
#         [876.5803,  63.9795, 939.0526, 172.8692]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.4574, 0.1424, 0.0531], device='cuda:0')}]
# Image 41 Predictions:
# [{'boxes': tensor([[780.9684,   0.0000, 972.1022,  72.6944]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9570], device='cuda:0')}]
# Image 42 Predictions:
# [{'boxes': tensor([[753.8297,  26.9923, 991.3931, 144.1684],
#         [577.0310, 225.9852, 652.2686, 283.6272],
#         [855.0797,  39.5261, 935.3604, 159.8242]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.6278, 0.4276, 0.0908], device='cuda:0')}]
# Image 43 Predictions:
# [{'boxes': tensor([[752.8261,  36.6733, 977.5225, 146.0491],
#         [860.7603,  47.9475, 923.2181, 155.1163]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7680, 0.1574], device='cuda:0')}]
# Image 44 Predictions:
# [{'boxes': tensor([[711.2720,   1.2965, 905.3859,  94.8806]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9544], device='cuda:0')}]
# Image 45 Predictions:
# [{'boxes': tensor([[725.3988,  21.2353, 949.0745, 130.1039],
#         [553.4323, 202.7303, 639.5798, 267.0684]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7038, 0.1673], device='cuda:0')}]
# Image 46 Predictions:
# [{'boxes': tensor([[763.7421,  38.6930, 976.1497, 147.0726],
#         [551.1481, 241.0513, 638.8159, 302.8649],
#         [847.0159,  45.2165, 916.5792, 157.7989]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.8922, 0.1389, 0.0889], device='cuda:0')}]
# Image 47 Predictions:
# [{'boxes': tensor([[735.0497,  39.5608, 993.6438, 147.9491],
#         [820.1792,  46.4778, 957.9381, 156.7376],
#         [847.0698,  49.1020, 916.8591, 157.6774],
#         [551.3568, 241.3913, 637.5872, 302.0809]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.5389, 0.2401, 0.0973, 0.0959], device='cuda:0')}]
# Image 48 Predictions:
# [{'boxes': tensor([[765.9980,  22.7341, 938.0043, 120.0973]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3491], device='cuda:0')}]
# Image 49 Predictions:
# [{'boxes': tensor([[ 774.2560,  267.3595, 1066.2253,  463.9073],
#         [ 819.6467,  177.6982, 1033.4653,  294.1070],
#         [ 867.4788,   50.5422, 1040.3364,  175.7694]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.5060, 0.3175, 0.2111], device='cuda:0')}]
# Image 50 Predictions:
# [{'boxes': tensor([[ 838.6207,  202.7879, 1045.6123,  338.1790],
#         [ 756.5979,  306.6469, 1084.4601,  508.2679],
#         [ 826.2010,   69.3584, 1030.1195,  178.6095],
#         [ 410.8134,  246.1711,  505.0302,  313.7437],
#         [ 910.4665,   77.9315,  971.2987,  192.9395]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.5718, 0.3860, 0.2033, 0.1292, 0.0534], device='cuda:0')}]
# Image 51 Predictions:
# [{'boxes': tensor([[ 837.8935,  259.0244, 1070.7350,  409.5896],
#         [ 834.5353,  376.6431, 1099.6729,  599.1617],
#         [ 810.4949,  105.8652, 1042.4720,  228.2156],
#         [ 873.3292,  404.1932, 1072.6464,  539.9890]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.3008, 0.2947, 0.1328, 0.1131], device='cuda:0')}]
# Image 52 Predictions:
# [{'boxes': tensor([[ 846.1873,  253.5445, 1057.3418,  386.7135],
#         [ 808.7696,   98.2991, 1047.7927,  223.1529],
#         [ 864.4864,  377.5161, 1095.6315,  599.0278]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.2212, 0.1470, 0.1099], device='cuda:0')}]
# Image 53 Predictions:
# [{'boxes': tensor([[ 422.6097,  223.3882,  563.1454,  333.4479],
#         [ 868.3160,   58.9948, 1039.7014,  182.9055],
#         [ 838.6473,  193.3412, 1048.5897,  324.4732]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.4728, 0.2687, 0.2510], device='cuda:0')}]
# Image 54 Predictions:
# [{'boxes': tensor([[ 422.3842,  223.8713,  566.6753,  333.5189],
#         [ 861.5455,   57.7006, 1040.9243,  183.8648],
#         [ 838.7202,  194.8993, 1048.3333,  325.7901]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.4676, 0.3072, 0.2348], device='cuda:0')}]
# Image 55 Predictions:
# [{'boxes': tensor([[ 422.3830,  223.8427,  560.5002,  335.3430],
#         [ 863.8401,   57.4814, 1043.3801,  182.8076],
#         [ 852.9705,  190.2664, 1042.7800,  315.9723],
#         [ 443.8802,  273.6800,  540.1788,  343.6156]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.4403, 0.2576, 0.2364, 0.1171], device='cuda:0')}]
# Image 56 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 57 Predictions:
# [{'boxes': tensor([[ 814.2637,  237.9930, 1094.2137,  432.7479],
#         [ 485.5107,  203.7182,  610.6155,  304.6364],
#         [ 894.3008,   43.0432, 1053.0437,  153.3969],
#         [ 832.2822,  162.0948, 1084.4714,  294.2644],
#         [ 497.8215,  148.0720,  600.1138,  216.3061]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.1733, 0.1448, 0.1247, 0.1078, 0.0517], device='cuda:0')}]
# Image 58 Predictions:
# [{'boxes': tensor([[ 798.4365,  236.7581, 1027.4613,  370.0656],
#         [ 742.4373,  336.1622, 1073.1958,  538.8020],
#         [ 844.1086,   84.0511, 1027.0747,  217.4942],
#         [ 363.4491,  211.4256,  482.9640,  275.4337],
#         [ 856.2869,  368.0143, 1044.9507,  499.5642]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.4763, 0.3568, 0.1290, 0.0630, 0.0533], device='cuda:0')}]
# Image 59 Predictions:
# [{'boxes': tensor([[ 786.0922,  229.7317, 1043.9453,  378.8949],
#         [ 738.9514,  343.9861, 1071.6176,  537.9963],
#         [ 819.0606,   85.8131, 1030.6309,  218.1165],
#         [ 360.5901,  210.6800,  485.0210,  281.5266]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.5613, 0.3544, 0.1109, 0.0597], device='cuda:0')}]
# Image 60 Predictions:
# [{'boxes': tensor([[ 782.8293,  224.6248, 1066.3359,  429.1408],
#         [ 871.6827,   38.9031, 1021.4163,  152.9252],
#         [ 781.3596,  170.8474,  910.6352,  271.2039],
#         [ 828.9623,  156.4895, 1058.4873,  291.7205]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.1811, 0.1493, 0.0657, 0.0536], device='cuda:0')}]
# Image 61 Predictions:
# [{'boxes': tensor([[ 482.5824,  176.6227,  609.6973,  277.8335],
#         [ 783.3882,  217.2906, 1066.3553,  414.9798],
#         [ 844.7848,   26.3561, 1047.6409,  144.1312],
#         [ 842.2322,  145.8329, 1040.5686,  274.4015],
#         [ 497.3975,  132.6668,  585.9368,  196.7066]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.3573, 0.2407, 0.2019, 0.1051, 0.0679], device='cuda:0')}]
# Image 62 Predictions:
# [{'boxes': tensor([[ 836.6417,  164.1924, 1036.0142,  291.7878],
#         [ 789.1793,  225.7601, 1057.6450,  419.6467]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.3323, 0.0961], device='cuda:0')}]
# Image 63 Predictions:
# [{'boxes': tensor([[ 827.1669,   78.9995, 1059.7996,  202.8381]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8149], device='cuda:0')}]
# Image 64 Predictions:
# [{'boxes': tensor([[ 827.2350,    0.0000, 1037.9694,   79.3657]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9735], device='cuda:0')}]
# Image 65 Predictions:
# [{'boxes': tensor([[ 806.6665,    9.3359, 1054.5770,   95.3385],
#         [ 894.9297,    7.7564, 1006.9521,  106.5149]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8878, 0.0905], device='cuda:0')}]
# Image 66 Predictions:
# [{'boxes': tensor([[ 805.1559,   31.8290, 1047.7830,  148.5048]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3310], device='cuda:0')}]
# Image 67 Predictions:
# [{'boxes': tensor([[ 882.0908,   67.5093, 1055.5432,  183.0432],
#         [ 798.3181,   56.8941, 1047.8070,  206.8943]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.4326, 0.1919], device='cuda:0')}]
# Image 68 Predictions:
# [{'boxes': tensor([[ 869.6998,    7.0066, 1085.1938,  103.5896]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0790], device='cuda:0')}]
# Image 69 Predictions:
# [{'boxes': tensor([[ 948.8496,  195.4700, 1138.9720,  323.0286],
#         [ 910.7697,  328.5840, 1130.9542,  461.5370]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.0977, 0.0957], device='cuda:0')}]
# Image 70 Predictions:
# [{'boxes': tensor([[ 866.4211,   95.0144, 1043.3679,  227.0658],
#         [ 932.2120,  250.1075, 1134.2399,  368.7447],
#         [ 850.8546,  418.8176,  987.6857,  522.8900],
#         [ 936.2410,  242.2403, 1170.3705,  481.0128],
#         [ 967.3278,  240.9722, 1092.9762,  318.3261]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.1698, 0.1014, 0.0780, 0.0747, 0.0565], device='cuda:0')}]
# Image 71 Predictions:
# [{'boxes': tensor([[ 946.6814,  260.7401, 1137.7280,  388.6652],
#         [ 933.1895,  241.7115, 1178.8608,  473.6530],
#         [ 859.1006,  104.4871, 1038.0403,  236.9204],
#         [ 858.6679,  444.0291,  978.9131,  538.9730]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.2850, 0.2016, 0.1553, 0.0702], device='cuda:0')}]
# Image 72 Predictions:
# [{'boxes': tensor([[ 934.5460,  241.5033, 1180.5909,  470.6237],
#         [ 940.6902,  261.8642, 1141.2245,  391.3093],
#         [ 903.0689,  434.6997, 1144.9738,  578.5781],
#         [ 858.0255,  443.2237,  979.5338,  538.4731]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.2024, 0.1768, 0.1167, 0.0551], device='cuda:0')}]
# Image 73 Predictions:
# [{'boxes': tensor([[ 925.2985,  239.2493, 1185.0988,  472.9513],
#         [ 897.0256,  433.8546, 1143.0001,  584.1908]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.2944, 0.1830], device='cuda:0')}]
# Image 74 Predictions:
# [{'boxes': tensor([[ 853.4656,  434.1306,  989.3212,  542.7382],
#         [ 905.4460,  433.1346, 1139.8970,  566.6637],
#         [ 950.8474,  267.9067, 1160.8438,  412.8958],
#         [ 866.2810,  102.3463, 1052.9517,  233.7617]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.2321, 0.1549, 0.1341, 0.0593], device='cuda:0')}]
# Image 75 Predictions:
# [{'boxes': tensor([[ 850.5076,   32.3015, 1042.3779,  156.5515]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1253], device='cuda:0')}]
# Image 76 Predictions:
# [{'boxes': tensor([[ 844.4412,    0.0000, 1029.9425,   89.0825],
#         [ 873.4508,  105.5847, 1054.6753,  224.9599]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.2702, 0.0932], device='cuda:0')}]
# Image 77 Predictions:
# [{'boxes': tensor([[ 840.7399,   22.9910, 1005.3876,  137.1068]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2664], device='cuda:0')}]
# Image 78 Predictions:
# [{'boxes': tensor([[829.5230,  47.1414, 972.8082, 161.3206]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1854], device='cuda:0')}]
# Image 79 Predictions:
# [{'boxes': tensor([[ 864.2599,  177.9530, 1064.3877,  299.6803]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0576], device='cuda:0')}]
# Image 80 Predictions:
# [{'boxes': tensor([[831.5747,  49.5062, 978.4490, 163.3172]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1034], device='cuda:0')}]
# Image 81 Predictions:
# [{'boxes': tensor([[ 850.0073,    9.3081, 1010.3422,  106.1805]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7979], device='cuda:0')}]
# Image 82 Predictions:
# [{'boxes': tensor([[ 826.8032,   53.2151, 1041.8083,  175.6458]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4401], device='cuda:0')}]
# Image 83 Predictions:
# [{'boxes': tensor([[ 812.6359,   94.7811, 1050.5599,  227.1407],
#         [ 854.9678,  244.0601, 1064.2188,  402.3945]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.4506, 0.2147], device='cuda:0')}]
# Image 84 Predictions:
# [{'boxes': tensor([[ 832.3453,   93.2667, 1054.9761,  223.1326],
#         [ 845.1457,  236.5796, 1091.0154,  479.4653]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8568, 0.1483], device='cuda:0')}]
# Image 85 Predictions:
# [{'boxes': tensor([[ 831.3065,   13.4582, 1041.8475,   98.4105]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4987], device='cuda:0')}]
# Image 86 Predictions:
# [{'boxes': tensor([[ 843.8702,    0.0000, 1027.6808,   65.8360]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8427], device='cuda:0')}]
# Image 87 Predictions:
# [{'boxes': tensor([[ 841.8022,   10.1770, 1034.2549,  118.1795]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2594], device='cuda:0')}]
# Image 88 Predictions:
# [{'boxes': tensor([[ 822.3702,   69.9770, 1060.3232,  183.0250]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3169], device='cuda:0')}]
# Image 89 Predictions:
# [{'boxes': tensor([[ 820.2942,   98.1978, 1043.0851,  225.8088],
#         [ 853.2200,  236.5267, 1094.1011,  471.5036]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.2255, 0.0592], device='cuda:0')}]
# Image 90 Predictions:
# [{'boxes': tensor([[ 856.3227,    7.5816, 1069.7690,   80.1372],
#         [ 928.6360,    0.0000, 1049.4688,   96.4567]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9475, 0.0506], device='cuda:0')}]
# Image 91 Predictions:
# [{'boxes': tensor([[ 860.1920,   30.6531, 1033.0035,  126.8087],
#         [ 659.3597,  204.9380,  725.5770,  259.5383]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.5233, 0.2954], device='cuda:0')}]
# Image 92 Predictions:
# [{'boxes': tensor([[ 832.6495,   48.4509, 1023.0208,  148.2460],
#         [ 615.1018,  234.3985,  689.6868,  292.3723],
#         [ 804.2675,   54.9149,  918.0682,  131.5346],
#         [ 917.2288,   57.6687,  979.1064,  165.5985]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.6013, 0.3512, 0.1064, 0.0710], device='cuda:0')}]
# Image 93 Predictions:
# [{'boxes': tensor([[ 860.5201,   72.2027, 1011.2426,  198.0358],
#         [ 877.5775,  706.7178, 1073.2202,  820.8770],
#         [ 896.5996,   86.4772,  960.8618,  198.9311]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.3489, 0.1849, 0.0837], device='cuda:0')}]
# Image 94 Predictions:
# [{'boxes': tensor([[ 840.6848,   92.6201, 1018.9813,  216.7353]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2283], device='cuda:0')}]
# Image 95 Predictions:
# [{'boxes': tensor([[ 723.9390,  113.4269, 1031.5702,  256.1145],
#         [ 853.9022,  123.4298,  994.8313,  248.2348]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8775, 0.2181], device='cuda:0')}]
# Image 96 Predictions:
# [{'boxes': tensor([[ 694.0773,  169.4741, 1050.6564,  330.0750],
#         [ 814.7285,  183.6288, 1001.6957,  306.9701],
#         [ 883.3366,  182.1087, 1088.7200,  316.5779]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.5537, 0.2794, 0.0584], device='cuda:0')}]
# Image 97 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 98 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 99 Predictions:
# [{'boxes': tensor([[822.5157, 774.8461, 911.1754, 837.5780]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0670], device='cuda:0')}]
# Image 100 Predictions:
# [{'boxes': tensor([[ 993.5213,  270.4263, 1251.8641,  503.0888],
#         [1007.5939,  138.3275, 1224.4778,  264.8533],
#         [ 668.7839,  930.5955,  783.4562, 1003.3097]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.2779, 0.0887, 0.0502], device='cuda:0')}]
# Image 101 Predictions:
# [{'boxes': tensor([[1038.8027,  337.1417, 1268.9583,  548.3524]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0899], device='cuda:0')}]
# Image 102 Predictions:
# [{'boxes': tensor([[747.1799,   0.0000, 934.9448,  62.6141]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7500], device='cuda:0')}]
# Image 103 Predictions:
# [{'boxes': tensor([[783.6655,   4.4984, 977.9065,  78.7257]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7677], device='cuda:0')}]
# Image 104 Predictions:
# [{'boxes': tensor([[ 856.2723,   25.3530, 1036.3616,  130.2319]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2872], device='cuda:0')}]
# Image 105 Predictions:
# [{'boxes': tensor([[ 909.9118,   52.5913, 1114.4691,  163.2858],
#         [ 910.6119,  176.8630, 1129.9355,  324.6487]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.1757, 0.1254], device='cuda:0')}]
# Image 106 Predictions:
# [{'boxes': tensor([[ 977.7289,   67.8168, 1173.1494,  189.8585]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0598], device='cuda:0')}]
# Image 107 Predictions:
# [{'boxes': tensor([[ 957.4341,   91.0401, 1170.8383,  215.0478]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4339], device='cuda:0')}]
# Image 108 Predictions:
# [{'boxes': tensor([[1013.9132,  189.7943, 1248.4348,  323.5626],
#         [1033.2843,  338.8347, 1271.9144,  555.1689]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.1798, 0.0832], device='cuda:0')}]
# Image 109 Predictions:
# [{'boxes': tensor([[ 859.3528,  144.6134, 1063.0034,  279.0770],
#         [ 871.1823,   36.7121, 1041.8354,  150.6913],
#         [ 838.5284,  149.7011, 1067.4885,  402.3142]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.5234, 0.4009, 0.0690], device='cuda:0')}]
# Image 110 Predictions:
# [{'boxes': tensor([[ 873.6867,   69.1073, 1078.7495,  194.0503],
#         [ 852.2969,  196.8183, 1054.3586,  319.7902]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.4186, 0.3379], device='cuda:0')}]
# Image 111 Predictions:
# [{'boxes': tensor([[ 838.1208,  103.5259, 1063.1110,  232.5273]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7053], device='cuda:0')}]
# Image 112 Predictions:
# [{'boxes': tensor([[ 799.9390,  160.1309, 1029.1010,  290.5382],
#         [ 774.5781,  290.9884, 1077.5153,  573.9748]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.3416, 0.2212], device='cuda:0')}]
# Image 113 Predictions:
# [{'boxes': tensor([[ 777.4466,  421.5068, 1127.6047,  610.5532]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2481], device='cuda:0')}]
# Image 114 Predictions:
# [{'boxes': tensor([[ 893.0345,  483.6909, 1079.1136,  589.9336],
#         [ 880.6113,  473.1723, 1098.5306,  677.7757]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.0643, 0.0552], device='cuda:0')}]
# Image 115 Predictions:
# [{'boxes': tensor([[ 790.8214,  469.2289, 1144.4723,  673.3705]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1375], device='cuda:0')}]
# Image 116 Predictions:
# [{'boxes': tensor([[ 905.1976,  544.6854, 1090.5115,  660.4888]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0694], device='cuda:0')}]
# Image 117 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 118 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 119 Predictions:
# [{'boxes': tensor([[1029.6722,  191.8973, 1253.7476,  322.5428],
#         [1044.0796,  343.3173, 1273.5476,  565.6499]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.4910, 0.1549], device='cuda:0')}]
# Image 120 Predictions:
# [{'boxes': tensor([[ 834.8042,  317.5540, 1093.7363,  559.1100]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3484], device='cuda:0')}]
# Image 121 Predictions:
# [{'boxes': tensor([[ 857.0278,  141.4495, 1081.4697,  273.2355]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1440], device='cuda:0')}]
# Image 122 Predictions:
# [{'boxes': tensor([[1020.3386,  143.8108, 1235.8429,  275.8568],
#         [ 945.8276,  284.8405, 1243.2791,  537.5507],
#         [ 998.3106,  308.8727, 1223.3718,  438.4454]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.5718, 0.3099, 0.2330], device='cuda:0')}]
# Image 123 Predictions:
# [{'boxes': tensor([[ 949.4968,   60.7073, 1114.3674,  175.1272],
#         [ 931.2528,  183.6688, 1131.8099,  317.2370]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.0935, 0.0780], device='cuda:0')}]
# Image 124 Predictions:
# [{'boxes': tensor([[ 869.9005,   12.3162, 1057.6893,  113.8598]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4964], device='cuda:0')}]
# Image 125 Predictions:
# [{'boxes': tensor([[ 854.3147,   16.1555, 1047.2300,   81.8784]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3578], device='cuda:0')}]
# Image 126 Predictions:
# [{'boxes': tensor([[ 826.2238,   68.4086, 1025.3744,  182.5381],
#         [ 866.7595,  203.3836, 1057.7345,  335.0392],
#         [ 849.7344,  192.9013, 1082.3175,  437.7762],
#         [ 878.7748,   63.6943, 1091.8792,  202.8021]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.6317, 0.2611, 0.2007, 0.0506], device='cuda:0')}]
# Image 127 Predictions:
# [{'boxes': tensor([[ 864.8843,  139.1079, 1064.2443,  271.0261],
#         [ 730.8515,  319.7223,  907.6160,  422.8694]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8309, 0.0545], device='cuda:0')}]
# Image 128 Predictions:
# [{'boxes': tensor([[ 844.8165,    0.0000, 1037.9452,   74.1810],
#         [ 855.8854,   84.6722, 1019.9158,  206.0281]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7684, 0.1329], device='cuda:0')}]
# Image 129 Predictions:
# [{'boxes': tensor([[ 822.0278,   29.1647, 1028.9703,  136.4465]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1913], device='cuda:0')}]
# Image 130 Predictions:
# [{'boxes': tensor([[ 823.2089,   82.4326, 1071.1416,  215.5067],
#         [ 842.0690,  224.3508, 1088.3083,  469.6428]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.3386, 0.1752], device='cuda:0')}]
# Image 131 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 132 Predictions:
# [{'boxes': tensor([[ 855.2396,  128.0268, 1057.6232,  256.4033]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.6174], device='cuda:0')}]
# Image 133 Predictions:
# [{'boxes': tensor([[ 827.4165,   37.2320, 1050.7388,  150.0261]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2741], device='cuda:0')}]
# Image 134 Predictions:
# [{'boxes': tensor([[ 832.2583,   54.9084, 1052.1073,  164.6891],
#         [ 924.6559,   58.1037,  995.8550,  183.0041],
#         [ 969.8276,  615.9836, 1092.0736,  683.3235]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.5301, 0.0786, 0.0598], device='cuda:0')}]
# Image 135 Predictions:
# [{'boxes': tensor([[ 881.1870,   25.3809, 1038.9584,  135.6126],
#         [ 945.6898,  530.5901, 1061.0018,  598.4297],
#         [ 965.4505,  537.7249, 1032.2192,  586.8748],
#         [ 947.9477,   40.1343, 1060.4463,  120.1873]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.3860, 0.1831, 0.1183, 0.0549], device='cuda:0')}]
# Image 136 Predictions:
# [{'boxes': tensor([[ 835.0934,   53.9088, 1050.1371,  165.5364],
#         [ 921.2911,   68.2103,  978.2648,  174.1246]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.5834, 0.1958], device='cuda:0')}]
# Image 137 Predictions:
# [{'boxes': tensor([[ 913.2624,  152.4458, 1061.1707,  282.2314]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2415], device='cuda:0')}]
# Image 138 Predictions:
# [{'boxes': tensor([[ 892.4791,  236.9716, 1106.4653,  422.4776]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2593], device='cuda:0')}]
# Image 139 Predictions:
# [{'boxes': tensor([[ 892.7889,  247.6065, 1095.4595,  425.0587]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1706], device='cuda:0')}]
# Image 140 Predictions:
# [{'boxes': tensor([[ 911.4093,  212.6681, 1078.9819,  332.5009],
#         [ 938.2078,  486.7673, 1008.8513,  621.4702],
#         [ 936.6378,  628.4770, 1013.9305,  680.0419]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.1652, 0.0643, 0.0572], device='cuda:0')}]
# Image 141 Predictions:
# [{'boxes': tensor([[ 759.4091,  110.9863, 1090.0892,  259.3920],
#         [ 861.8500,  118.3421, 1054.4193,  239.6404],
#         [ 924.3403,  128.6204,  983.2848,  248.9923]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.6855, 0.1152, 0.0962], device='cuda:0')}]
# Image 142 Predictions:
# [{'boxes': tensor([[ 768.9409,   94.3198, 1091.8350,  251.0019],
#         [ 889.3558,  108.5992, 1059.3871,  238.9274],
#         [ 926.9911,  115.1994,  994.5336,  236.7836],
#         [ 916.9841,  126.2421, 1040.7831,  212.4887]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.5744, 0.3854, 0.3789, 0.0677], device='cuda:0')}]
# Image 143 Predictions:
# [{'boxes': tensor([[ 837.6149,    0.0000, 1011.9827,   74.2460]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9144], device='cuda:0')}]
# Image 144 Predictions:
# [{'boxes': tensor([[ 880.2094,   19.8680, 1028.9620,  114.3101]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.5342], device='cuda:0')}]
# Image 145 Predictions:
# [{'boxes': tensor([[ 924.3626,   42.9995, 1087.2456,  155.5666]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1713], device='cuda:0')}]
# Image 146 Predictions:
# [{'boxes': tensor([[ 928.9966,   53.8032, 1105.1908,  172.5822]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1934], device='cuda:0')}]
# Image 147 Predictions:
# [{'boxes': tensor([[ 900.0050,   60.3002, 1114.8127,  177.5997]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7800], device='cuda:0')}]
# Image 148 Predictions:
# [{'boxes': tensor([[ 871.0073,   17.9756, 1090.8812,  118.2736]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2438], device='cuda:0')}]
# Image 149 Predictions:
# [{'boxes': tensor([[ 846.0432,    0.0000, 1029.3795,   86.8462]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7705], device='cuda:0')}]
# Image 150 Predictions:
# [{'boxes': tensor([[ 919.2078,   45.8408, 1097.8345,  141.8585]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1060], device='cuda:0')}]
# Image 151 Predictions:
# [{'boxes': tensor([[1028.4211,   75.2391, 1196.4341,  198.1258]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4137], device='cuda:0')}]
# Image 152 Predictions:
# [{'boxes': tensor([[ 930.8403,   30.6736, 1112.4102,  138.4395]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2132], device='cuda:0')}]
# Image 153 Predictions:
# [{'boxes': tensor([[ 834.7786,    0.0000, 1007.3913,   73.1639]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7914], device='cuda:0')}]
# Image 154 Predictions:
# [{'boxes': tensor([[ 846.0756,   32.9342, 1018.9833,  124.7627]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3503], device='cuda:0')}]
# Image 155 Predictions:
# [{'boxes': tensor([[ 897.1934,   51.5311, 1059.4172,  172.9253]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1508], device='cuda:0')}]
# Image 156 Predictions:
# [{'boxes': tensor([[ 897.4850,   75.8997, 1057.5028,  197.6647]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4799], device='cuda:0')}]
# Image 157 Predictions:
# [{'boxes': tensor([[ 851.4969,   96.2878, 1070.3538,  211.9924]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.6123], device='cuda:0')}]
# Image 158 Predictions:
# [{'boxes': tensor([[ 872.0411,  118.1343, 1095.2922,  244.0893]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.5852], device='cuda:0')}]
# Image 159 Predictions:
# [{'boxes': tensor([[ 875.8391,  135.7309, 1099.6621,  254.8403]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.4816], device='cuda:0')}]
# Image 160 Predictions:
# [{'boxes': tensor([[ 803.2037,   19.2816, 1001.1184,  132.5421]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2805], device='cuda:0')}]
# Image 161 Predictions:
# [{'boxes': tensor([[761.9997,   0.0000, 980.0425,  78.1712]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8191], device='cuda:0')}]
# Image 162 Predictions:
# [{'boxes': tensor([[781.5001,   0.0000, 964.5563,  71.8973],
#         [758.3353, 155.6490, 992.4559, 289.6671]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7926, 0.0692], device='cuda:0')}]
# Image 163 Predictions:
# [{'boxes': tensor([[784.1420,  11.7881, 985.5223,  98.2451]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.6257], device='cuda:0')}]
# Image 164 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 165 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 166 Predictions:
# [{'boxes': tensor([[ 967.3413,  156.0015, 1176.4246,  280.1104]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2207], device='cuda:0')}]
# Image 167 Predictions:
# [{'boxes': tensor([[719.2906,   5.2727, 929.8511,  80.1076]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7657], device='cuda:0')}]
# Image 168 Predictions:
# [{'boxes': tensor([[741.8276,   9.5702, 949.3477,  99.6290]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3037], device='cuda:0')}]
# Image 169 Predictions:
# [{'boxes': tensor([[776.3380,  20.7281, 998.3711, 104.2733]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2246], device='cuda:0')}]
# Image 170 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 171 Predictions:
# [{'boxes': tensor([[ 836.3975,   33.0392, 1051.8179,  151.7321]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0583], device='cuda:0')}]
# Image 172 Predictions:
# [{'boxes': tensor([[ 975.2875,  154.7509, 1190.9851,  276.0300]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1248], device='cuda:0')}]
# Image 173 Predictions:
# [{'boxes': tensor([[ 859.0405,    8.1331, 1068.0350,  113.1301]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2262], device='cuda:0')}]
# Image 174 Predictions:
# [{'boxes': tensor([[ 843.9329,   53.6408, 1085.4242,  160.3322],
#         [ 794.8583,  290.2833, 1144.0118,  474.3582],
#         [ 958.0550,  406.6792, 1051.4451,  473.7241]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.3625, 0.0602, 0.0542], device='cuda:0')}]
# Image 175 Predictions:
# [{'boxes': tensor([[ 859.1807,   96.9590, 1072.5945,  224.5239]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.5366], device='cuda:0')}]
# Image 176 Predictions:
# [{'boxes': tensor([[ 904.4263,  115.8903, 1119.2733,  248.8573]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0926], device='cuda:0')}]
# Image 177 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 178 Predictions:
# [{'boxes': tensor([[ 881.8262,    7.2260, 1067.0551,  115.3675]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2936], device='cuda:0')}]
# Image 179 Predictions:
# [{'boxes': tensor([[ 878.6196,    7.1052, 1068.9199,  122.8509]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1139], device='cuda:0')}]
# Image 180 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 181 Predictions:
# [{'boxes': tensor([[ 916.8659,   69.7151, 1126.1067,  207.0999],
#         [1014.4399,   84.2895, 1133.2483,  158.4724]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.0640, 0.0534], device='cuda:0')}]
# Image 182 Predictions:
# [{'boxes': tensor([[512.1801,   0.0000, 652.3246,  49.0817]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8793], device='cuda:0')}]
# Image 183 Predictions:
# [{'boxes': tensor([[533.4186,   0.0000, 647.6034,  55.9731],
#         [524.2693,  54.6689, 657.7398, 149.8898],
#         [544.6887,  60.8085, 643.6971, 122.1015]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.7729, 0.1134, 0.0980], device='cuda:0')}]
# Image 184 Predictions:
# [{'boxes': tensor([[529.4999,   5.2529, 649.8002,  51.7439],
#         [547.5297,  67.2398, 642.9675, 123.5956]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8889, 0.0787], device='cuda:0')}]
# Image 185 Predictions:
# [{'boxes': tensor([[531.2225,   8.4360, 658.6554,  60.2153],
#         [553.2382,  72.3105, 642.6579, 127.7036]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.6861, 0.1159], device='cuda:0')}]
# Image 186 Predictions:
# [{'boxes': tensor([[547.1353,   5.1733, 670.5645,  79.8290]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.6799], device='cuda:0')}]
# Image 187 Predictions:
# [{'boxes': tensor([[564.6677,  38.1828, 732.3522, 130.7897],
#         [556.0457, 123.6628, 727.3966, 295.8059]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.2465, 0.0520], device='cuda:0')}]
# Image 188 Predictions:
# [{'boxes': tensor([[561.5293,  41.6035, 736.0143, 131.6211],
#         [562.9590, 124.8276, 725.9741, 292.1716],
#         [571.6556, 139.6364, 712.2916, 223.0501]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.2098, 0.1816, 0.0656], device='cuda:0')}]
# Image 189 Predictions:
# [{'boxes': tensor([[610.3762,  51.7163, 726.2968, 137.2127]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1443], device='cuda:0')}]
# Image 190 Predictions:
# [{'boxes': tensor([[563.8963,  54.2203, 728.8181, 143.0542],
#         [569.2574, 150.1835, 729.9719, 257.7451]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.4544, 0.0574], device='cuda:0')}]
# Image 191 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 192 Predictions:
# [{'boxes': tensor([[571.2454,  69.2811, 724.4836, 156.3330],
#         [571.8528, 159.7717, 731.1356, 327.4150]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7622, 0.0839], device='cuda:0')}]
# Image 193 Predictions:
# [{'boxes': tensor([[553.5811,  73.1888, 720.2462, 154.5195]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.5725], device='cuda:0')}]
# Image 194 Predictions:
# [{'boxes': tensor([[547.3934,  11.5276, 673.5145,  85.3160]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.6291], device='cuda:0')}]
# Image 195 Predictions:
# [{'boxes': tensor([[558.9955,  23.3081, 674.0327,  98.2511]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2987], device='cuda:0')}]
# Image 196 Predictions:
# [{'boxes': tensor([[573.0267,  17.9177, 692.6646,  95.4930],
#         [557.2311, 101.0464, 687.2905, 183.4072]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.2950, 0.0759], device='cuda:0')}]
# Image 197 Predictions:
# [{'boxes': tensor([[557.8605,  25.1391, 691.2554,  97.5234],
#         [567.4969, 105.0054, 702.1495, 193.8029]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.6100, 0.1113], device='cuda:0')}]
# Image 198 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 199 Predictions:
# [{'boxes': tensor([[560.3473,  31.4843, 705.0150, 114.9475]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2294], device='cuda:0')}]
# Image 200 Predictions:
# [{'boxes': tensor([[559.4933,  36.0792, 705.1733, 118.1006]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.3080], device='cuda:0')}]
# Image 201 Predictions:
# [{'boxes': tensor([[572.2595,  33.7300, 714.9174, 115.3447]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.2202], device='cuda:0')}]
# Image 202 Predictions:
# [{'boxes': tensor([[526.4988,   4.7690, 668.8317,  54.1525],
#         [572.1696,   0.0000, 651.9543,  61.8073]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8959, 0.1169], device='cuda:0')}]
# Image 203 Predictions:
# [{'boxes': tensor([[530.8560,   9.1217, 678.6788,  66.9452],
# ...
# Image 696 Predictions:
# [{'boxes': tensor([[639.7210, 450.1087, 784.2867, 541.8163]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0611], device='cuda:0')}]
# Image 697 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 698 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 699 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 700 Predictions:
# [{'boxes': tensor([[638.1527, 307.2358, 781.2415, 394.8789],
#         [336.0649, 481.3626, 410.8362, 537.9291],
#         [313.7109, 473.8698, 421.4567, 552.6723],
#         [519.4113, 474.1867, 643.4555, 562.2735]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.5361, 0.1544, 0.0715, 0.0701], device='cuda:0')}]
# Image 701 Predictions:
# [{'boxes': tensor([[321.1267, 486.6131, 414.5138, 560.9916],
#         [592.7986, 305.7832, 793.4025, 421.2455],
#         [764.1843, 325.1144, 832.9692, 368.4172]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.3646, 0.0956, 0.0772], device='cuda:0')}]
# Image 702 Predictions:
# [{'boxes': tensor([[313.2452, 489.4620, 414.7088, 562.9561],
#         [592.1470, 306.1864, 791.9308, 423.1998],
#         [768.0605, 328.0168, 835.4819, 373.9876]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.1788, 0.1556, 0.0952], device='cuda:0')}]
# Image 703 Predictions:
# [{'boxes': tensor([[583.5469, 312.0085, 786.3212, 425.7446],
#         [315.5163, 497.2237, 410.6778, 574.4075],
#         [662.6382, 506.2280, 713.8279, 549.2747]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.5194, 0.2058, 0.0618], device='cuda:0')}]
# Image 704 Predictions:
# [{'boxes': tensor([[520.2271, 511.1677, 631.2216, 594.9323],
#         [645.4059, 334.6289, 778.8319, 423.5645]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.1080, 0.1021], device='cuda:0')}]
# Image 705 Predictions:
# [{'boxes': tensor([[660.2845, 544.0356, 716.0552, 587.8267],
#         [628.5901, 332.4553, 778.9118, 457.4210]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.1509, 0.1210], device='cuda:0')}]
# Image 706 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 707 Predictions:
# [{'boxes': tensor([[647.9230, 405.7759, 787.9128, 502.7365]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0957], device='cuda:0')}]
# Image 708 Predictions:
# [{'boxes': tensor([[669.3633, 100.7502, 749.4492, 146.0244],
#         [696.9348,  99.3333, 740.5513, 177.4427]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9338, 0.1032], device='cuda:0')}]
# Image 709 Predictions:
# [{'boxes': tensor([[670.0308, 104.1102, 758.1954, 153.1032],
#         [708.1351, 104.0871, 752.7891, 178.2640],
#         [656.5117, 102.4694, 761.8242, 186.8996],
#         [652.1104, 164.7957, 757.1601, 245.2680]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.9832, 0.3205, 0.1445, 0.0621], device='cuda:0')}]
# Image 710 Predictions:
# [{'boxes': tensor([[679.9307, 110.2609, 765.1543, 157.2191],
#         [712.8337, 109.0415, 757.0529, 185.7014]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9403, 0.0678], device='cuda:0')}]
# Image 711 Predictions:
# [{'boxes': tensor([[684.4780, 114.4476, 773.5824, 164.8843],
#         [718.5477, 116.1549, 762.5784, 196.0022]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9691, 0.1045], device='cuda:0')}]
# Image 712 Predictions:
# [{'boxes': tensor([[688.3825, 118.5456, 780.5620, 172.9022],
#         [663.1479, 109.4479, 786.1099, 200.6091],
#         [704.5600, 226.5909, 779.2250, 276.2061]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.9683, 0.1101, 0.0689], device='cuda:0')}]
# Image 713 Predictions:
# [{'boxes': tensor([[698.4963, 128.3002, 789.8741, 183.5301]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9348], device='cuda:0')}]
# Image 714 Predictions:
# [{'boxes': tensor([[707.1980, 136.1917, 798.6024, 191.0682],
#         [670.3074, 127.9178, 807.3720, 204.1669]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8925, 0.4887], device='cuda:0')}]
# Image 715 Predictions:
# [{'boxes': tensor([[653.0742,  88.6177, 724.4985, 133.1955]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7018], device='cuda:0')}]
# Image 716 Predictions:
# [{'boxes': tensor([[652.1078,  89.1185, 736.7087, 136.7159]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9585], device='cuda:0')}]
# Image 717 Predictions:
# [{'boxes': tensor([[659.9016,  96.3622, 741.1683, 138.5135],
#         [692.8793,  99.1875, 737.8588, 141.1710],
#         [649.8750,  96.1164, 747.1541, 169.8291]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.9422, 0.0901, 0.0734], device='cuda:0')}]
# Image 718 Predictions:
# [{'boxes': tensor([[681.1316, 107.8904, 762.0660, 156.1432],
#         [660.7447, 107.1253, 763.2856, 187.0029],
#         [711.0184, 105.9213, 752.4152, 177.9005]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.9653, 0.3597, 0.0799], device='cuda:0')}]
# Image 719 Predictions:
# [{'boxes': tensor([[694.5648, 170.0793, 840.7590, 248.1854],
#         [761.4630, 176.3897, 812.1889, 257.3102],
#         [540.1734, 295.8405, 603.0522, 340.1078],
#         [775.2719, 180.7112, 853.9993, 235.9229]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.5012, 0.1887, 0.1520, 0.1170], device='cuda:0')}]
# Image 720 Predictions:
# [{'boxes': tensor([[698.9742, 192.0417, 858.9021, 267.7681],
#         [774.9792, 195.8215, 826.1888, 287.0188],
#         [525.9379, 331.3921, 588.8758, 377.6001],
#         [758.4816, 201.7857, 841.8510, 263.7820]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.7591, 0.1736, 0.1487, 0.0658], device='cuda:0')}]
# Image 721 Predictions:
# [{'boxes': tensor([[736.8723, 218.4257, 879.2846, 303.9929],
#         [657.7252, 359.8120, 764.3390, 442.1773],
#         [653.1647, 354.8418, 899.8912, 520.2814],
#         [839.0513, 237.4730, 915.5961, 286.6615]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.5318, 0.0706, 0.0534, 0.0529], device='cuda:0')}]
# Image 722 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 723 Predictions:
# [{'boxes': tensor([[803.8447, 279.6386, 911.5773, 369.8312]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0584], device='cuda:0')}]
# Image 724 Predictions:
# [{'boxes': tensor([[893.6331, 284.3179, 970.4474, 339.4658]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1141], device='cuda:0')}]
# Image 725 Predictions:
# [{'boxes': tensor([[686.4874, 112.1806, 770.8862, 160.8353],
#         [664.7671, 106.9644, 768.6985, 189.6402],
#         [714.4819, 110.0439, 759.1891, 189.2117]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.9634, 0.1190, 0.1014], device='cuda:0')}]
# Image 726 Predictions:
# [{'boxes': tensor([[685.3342, 115.9366, 774.3339, 165.3158],
#         [710.4642, 121.9097, 761.8822, 163.4177]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9771, 0.0581], device='cuda:0')}]
# Image 727 Predictions:
# [{'boxes': tensor([[694.3557, 122.9458, 784.1230, 176.7414],
#         [719.7169, 116.9845, 774.7620, 202.4944]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9660, 0.0524], device='cuda:0')}]
# Image 728 Predictions:
# [{'boxes': tensor([[696.0057, 129.7048, 791.0408, 186.2548],
#         [663.4585, 209.7173, 790.3047, 300.6654],
#         [709.5604, 244.8966, 789.1436, 298.0632]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.9665, 0.1368, 0.1291], device='cuda:0')}]
# Image 729 Predictions:
# [{'boxes': tensor([[705.0038, 137.5377, 794.4006, 192.8304],
#         [661.4734, 223.2109, 797.7706, 315.8902],
#         [567.2315, 227.3991, 626.1110, 268.2661]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.8974, 0.0590, 0.0507], device='cuda:0')}]
# Image 730 Predictions:
# [{'boxes': tensor([[703.5433, 140.1322, 808.6190, 206.6893],
#         [727.6879, 149.1234, 793.6750, 199.7018],
#         [565.2578, 241.8740, 613.4278, 283.9724]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.7988, 0.1795, 0.1168], device='cuda:0')}]
# Image 731 Predictions:
# [{'boxes': tensor([[714.6060, 148.2612, 819.6862, 218.5299],
#         [556.9009, 253.8525, 607.6562, 297.4680]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8742, 0.0763], device='cuda:0')}]
# Image 732 Predictions:
# [{'boxes': tensor([[725.8683, 156.3759, 822.4149, 230.1968],
#         [548.7732, 269.9399, 601.1778, 313.9876]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7076, 0.1872], device='cuda:0')}]
# Image 733 Predictions:
# [{'boxes': tensor([[654.0454, 103.4309, 742.4172, 152.1349],
#         [679.9338, 110.5143, 733.6685, 150.2905]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9771, 0.0816], device='cuda:0')}]
# Image 734 Predictions:
# [{'boxes': tensor([[611.0680, 214.4375, 766.6974, 301.7379]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.6780], device='cuda:0')}]
# Image 735 Predictions:
# [{'boxes': tensor([[632.3797, 243.9587, 783.5070, 358.7285]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0509], device='cuda:0')}]
# Image 736 Predictions:
# [{'boxes': tensor([[498.3710, 511.5521, 621.6099, 604.0369],
#         [651.0770, 317.2207, 780.4064, 411.5065]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.0948, 0.0503], device='cuda:0')}]
# Image 737 Predictions:
# [{'boxes': tensor([[650.6974, 632.3043, 716.3216, 684.7508]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.1419], device='cuda:0')}]
# Image 738 Predictions:
# [{'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}]
# Image 739 Predictions:
# [{'boxes': tensor([[658.6696, 107.9066, 743.3579, 157.7739],
#         [657.5022, 202.2274, 741.1600, 254.8858]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9801, 0.0617], device='cuda:0')}]
# Image 740 Predictions:
# [{'boxes': tensor([[648.7281, 113.3815, 746.3710, 162.9818],
#         [629.9642, 180.8488, 745.6158, 268.7124],
#         [685.6552, 117.7574, 742.9761, 169.7330],
#         [560.4653, 348.9998, 672.3115, 427.9297]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.9241, 0.0987, 0.0629, 0.0612], device='cuda:0')}]
# Image 741 Predictions:
# [{'boxes': tensor([[663.4305, 121.0224, 750.3860, 176.2422],
#         [624.6603, 191.5025, 751.4855, 285.3421]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9008, 0.0790], device='cuda:0')}]
# Image 742 Predictions:
# [{'boxes': tensor([[654.4825, 119.0881, 754.3123, 187.3895],
#         [676.4464, 246.2178, 753.2945, 297.6170],
#         [687.9552, 125.8573, 736.2086, 190.8524]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.9487, 0.0974, 0.0608], device='cuda:0')}]
# Image 743 Predictions:
# [{'boxes': tensor([[650.7914, 135.8040, 753.1885, 193.8113]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8953], device='cuda:0')}]
# Image 744 Predictions:
# [{'boxes': tensor([[657.6984, 142.5076, 759.0601, 212.8807],
#         [690.3860, 148.8623, 729.4152, 218.6376],
#         [627.6152, 151.0334, 684.4206, 195.5800],
#         [512.6298, 249.0542, 562.0798, 288.8705]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.8632, 0.0757, 0.0676, 0.0513], device='cuda:0')}]
# Image 745 Predictions:
# [{'boxes': tensor([[632.6313, 160.8162, 757.2236, 227.2888],
#         [486.0536, 272.9143, 539.2010, 314.2586],
#         [687.8153, 161.5341, 732.1633, 236.0087]], device='cuda:0'), 'labels': tensor([1, 1, 1], device='cuda:0'), 'scores': tensor([0.7384, 0.1766, 0.0797], device='cuda:0')}]
# Image 746 Predictions:
# [{'boxes': tensor([[623.4195, 177.0245, 771.9054, 256.1568],
#         [455.4793, 314.1979, 508.4675, 359.9847],
#         [685.7676, 189.3929, 730.7689, 268.9179],
#         [598.2616, 186.9051, 680.3957, 241.5495],
#         [677.4663, 194.2671, 747.9432, 249.2029]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.8252, 0.1244, 0.1244, 0.0660, 0.0524], device='cuda:0')}]
# Image 747 Predictions:
# [{'boxes': tensor([[660.7476,  93.5826, 736.9866, 141.3257],
#         [647.9850,  96.8451, 739.4001, 171.1364]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.9815, 0.1134], device='cuda:0')}]
# Image 748 Predictions:
# [{'boxes': tensor([[642.6718, 117.8822, 743.3751, 181.7884],
#         [659.9375, 238.0641, 740.7629, 291.1227],
#         [607.7422, 232.4235, 743.3718, 314.2955],
#         [621.8975, 192.7931, 698.6993, 319.8210]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.8552, 0.1028, 0.0815, 0.0738], device='cuda:0')}]
# Image 749 Predictions:
# [{'boxes': tensor([[632.2261, 129.5868, 746.4609, 197.5516],
#         [662.8597, 136.4363, 734.6976, 190.3806]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8808, 0.1875], device='cuda:0')}]
# Image 750 Predictions:
# [{'boxes': tensor([[639.1209, 143.0846, 750.8493, 203.3237],
#         [511.1211, 242.2708, 558.7892, 284.0651]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.8979, 0.1729], device='cuda:0')}]
# Image 751 Predictions:
# [{'boxes': tensor([[658.1490, 152.0196, 763.2142, 224.7241],
#         [498.2339, 264.0554, 552.3699, 307.7537]], device='cuda:0'), 'labels': tensor([1, 1], device='cuda:0'), 'scores': tensor([0.7740, 0.1972], device='cuda:0')}]
# Image 752 Predictions:
# [{'boxes': tensor([[630.7579, 161.2496, 768.5150, 229.8680],
#         [490.3572, 274.4505, 545.2309, 315.5923],
#         [693.1822, 164.1729, 738.4571, 242.0131],
#         [671.9496, 166.2462, 749.6475, 223.8143]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.9575, 0.4862, 0.1065, 0.1057], device='cuda:0')}]
# Image 753 Predictions:
# [{'boxes': tensor([[636.7786, 164.6089, 763.8663, 233.3869],
#         [485.5394, 280.3608, 540.7488, 321.5837],
#         [672.8922, 169.6871, 794.1302, 242.2608],
#         [694.6581, 168.7553, 741.0431, 248.1208]], device='cuda:0'), 'labels': tensor([1, 1, 1, 1], device='cuda:0'), 'scores': tensor([0.8516, 0.2926, 0.0556, 0.0547], device='cuda:0')}]
# Image 754 Predictions:
# [{'boxes': tensor([[647.2059, 110.4779, 732.5142, 158.4912]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9556], device='cuda:0')}]
# Image 755 Predictions:
# [{'boxes': tensor([[643.8002, 111.6657, 738.0280, 165.2304]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9533], device='cuda:0')}]

# %%
from package.function import *
predictions = predictions_to_coco_json_ssd(results,file)
xml_path = '資料集/貨櫃資料集/測試集_xml/'
ground_truths = xmls_to_coco_json(xml_path)

# %%
metric = compute_metrics(predictions, ground_truths)
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.24s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.723
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.334

# %%
metric
# Out:
# {'mAP50': 0.7231657894128081,
#  'mAP50-95': 0.08143047949930274,
#  'Precision': 0.2883232414592709,
#  'Recall': 0.36596026490066225,
#  'F1-Score': 0.3225355638520613}

# %% [markdown]
# # ***圖片準確率測試集 貨櫃編號偵測***

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from package.function import *
import easyocr,cv2,re

# 初始化 easyOCR
reader = easyocr.Reader(['en'], gpu=False)

def remove_non_alphanumeric_and_uppercase(s):
    # 使用正則表達式過濾掉非英文和數字的字符
    cleaned_str = re.sub(r'[^a-zA-Z0-9]', '', s)
    # 將剩餘的字串轉換為大寫
    return cleaned_str.upper()

def visualize_detections(results, filepaths, original_images):
    for i, (result, img_tensor) in enumerate(zip(results, original_images)):
        img = (img_tensor.permute(1, 2, 0).cpu().numpy()*255).astype('uint8')
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12, 8))
        plt.imshow(img_rgb)
        ax = plt.gca()

        for box, score in zip(result['boxes'].cpu(), result['scores'].cpu()):
            if score >0.5:
                x1, y1, x2, y2 = box.tolist()
                width, height = x2 - x1, y2 - y1

                rect = Rectangle((x1, y1), width, height, linewidth=2, edgecolor='red', facecolor='none')
                ax.add_patch(rect)

                crop_img = img_rgb[int(y1):int(y2), int(x1):int(x2)]

                try:
                    result_ocr = reader.readtext(crop_img)
                    result_ocr = [remove_non_alphanumeric_and_uppercase(res[1]) for res in result_ocr]
                    if len(result_ocr) > 0:
                        recognized_text = result_ocr[0]
                        if len(recognized_text) > 11:
                            recognized_text = recognized_text[:11]
                    else:
                        recognized_text = 'No Text'
                except Exception as e:
                    print("OCR failed:", e)
                    recognized_text = 'OCR Error'

                ax.text(x1, y2, f'{recognized_text}', color='yellow', fontsize=12, bbox=dict(facecolor='blue', alpha=0.5))

        plt.axis('off')
        plt.savefig(filepaths[i])
        plt.close()
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
# 圖片預測
import torch
from package.function import *
# 用最佳model進行物件偵測
model = torch.load("best_model/Rcnn.pth")

folderpath = '資料集/圖片準確率測試集/'
filenames = find_filename(folder_path=folderpath,File_extension='jpg')[0]
file = [folderpath+filename for filename in filenames]


# torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = "cpu"
model = model.to(device)
images = load_images(file)
images = [image.to(device) for image in images]  # 將圖像移動到相同的設備

model.eval()
results = model(images)

# images = load_images(file)
visualize_detections(results,[folderpath+'object_rcnn/'+filename for filename in filenames],images)

# %% [markdown]
# # ***影片 貨櫃編號偵測***

# %%
import cv2,re,easyocr
from package.function import *
from torchvision.transforms import functional as F

reader = easyocr.Reader(['en'], gpu=False)

def remove_non_alphanumeric_and_uppercase(s):
    # 使用正則表達式過濾掉非英文和數字的字符
    cleaned_str = re.sub(r'[^a-zA-Z0-9]', '', s)
    # 將剩餘的字串轉換為大寫
    return cleaned_str.upper()

# 處理影片
def process_video(video_path, save_path, model, device):
    cap = cv2.VideoCapture(video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(save_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img_tensor = F.to_tensor(img_rgb).unsqueeze(0).to(device)

        with torch.no_grad():
            results = model(img_tensor)

        output_frame = draw_detections(frame, results, device)
        out.write(output_frame)

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# 在影像中繪製偵測結果
def draw_detections(frame, results, device):
    if results:
        result = results[0]
        boxes = result['boxes'].cpu().numpy()
        labels = result['labels'].cpu().numpy()
        scores = result['scores'].cpu().numpy()

        for box, score, label in zip(boxes, scores, labels):
            if score < 0.5:  # 設定一個分數閾值
                continue

            x1, y1, x2, y2 = map(int, box)

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)

            crop_img = frame[y1:y2, x1:x2]

            try:
                result_ocr = reader.readtext(crop_img)
                if result_ocr:
                    recognized_text = ' '.join([remove_non_alphanumeric_and_uppercase(res[1]) for res in result_ocr])

                    if len(recognized_text) > 11:
                        recognized_text = recognized_text[:11]
                else:
                    recognized_text = 'No Text'
            except Exception as e:
                print("OCR failed:", e)
                recognized_text = 'OCR Error'

            cv2.putText(frame, recognized_text, (x1, y2 + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)

    return frame
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
import torch
from package.function import *
model = torch.load("best_model/Rcnn.pth")
filenames = find_filename(folder_path='資料集/影片資料集/',File_extension='avi')[0]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()
for filename in filenames:
    # 影片路徑
    video_path = f'資料集/影片資料集/{filename}'

    save_path = f'資料集/影片資料集/output_rcnn/{filename}'
    # 處理影片
    process_video(video_path,save_path, model,device)
